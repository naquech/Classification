# %%
import pandas as pd

# %%
columns = ['age', 'workclass', 'fnlwgt', 'education', 'education_num', 'marital_status', 'occupation', 'relationship',
          'race', 'sex', 'capital_gain', 'capital_loss', 'hours_per_week', 'native_country', 'income']

data = pd.read_csv('data/adult.data', names=columns, sep=' *, *', engine='python')
test = pd.read_csv('data/adult.test', names=columns, skiprows=1, sep=' *, *', engine='python')

data_full = pd.concat([data, test])

# %%
type(data_full)
# Out:
# pandas.core.frame.DataFrame

# %%
data_full.head()
# Out:
#    age         workclass  fnlwgt  education  education_num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital_status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital_gain  capital_loss  hours_per_week native_country income
# 0          2174             0              40  United-States  <=50K
# ...

# %%
data_full.loc[data_full['income'] == '<=50K.', 'income'] = '<=50K'
data_full.loc[data_full['income'] == '>50K.', 'income'] = '>50K'

# %%
import numpy as np
from sklearn import preprocessing

# %%
def encode_features(df):
    result = df.copy()
    encoders = {}
    for column in result.columns:
        if result.dtypes[column] == np.object:
            encoders[column] = preprocessing.LabelEncoder()
            result[column] = encoders[column].fit_transform(result[column])
    return result, encoders

# %%
df_encoded, _ = encode_features(data_full)
df_encoded.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  race  sex  capital_gain  capital_loss  \
# 0           1             1     4    1          2174             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    hours_per_week  native_country  income
# 0              40              39       0
# 1              13              39       0
# ...

# %%
import matplotlib.pyplot as plt

# %%
# a simple line plot
df_encoded.groupby('income')['age'].nunique().plot(kind='bar')
plt.show()

# %%
fig = plt.figure(figsize=(15,25))
cols = 3
rows = math.ceil(float(data_full.shape[1])/cols)

for i, column in enumerate(data_full.columns):
    ax = fig.add_subplot(rows, cols, i + 1)
    ax.set_title(column)
    if data_full.dtypes[column] == np.object:
        
    else:
        data_full[column].hist(axes=ax)
        plt.xticks(rotation="vertical")
        
plt.subplots_adjust(hspace=1.0, wspace=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-068b7cc2935c> in <module>()
#      13         data_full.groupby(['occupation','income']).size().unstack().plot(kind='bar',stacked=True)
#      14     else:
# ---> 15         data_full[column].hist(axes=ax)
#      16         plt.xticks(rotation="vertical")
#      17
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2479         values = self.dropna().values
#    2480
# -> 2481         ax.hist(values, bins=bins, **kwds)
#    2482         ax.grid(grid)
#    2483         axes = np.array([ax])
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
import math 

data_full.groupby(['workclass','income']).size().unstack().plot(kind='bar',stacked=True, subplots=True)
data_full.groupby(['education','income']).size().unstack().plot(kind='bar',stacked=True)
data_full.groupby(['marital_status','income']).size().unstack().plot(kind='bar',stacked=True)
data_full.groupby(['occupation','income']).size().unstack().plot(kind='bar',stacked=True)
data_full.groupby(['relationship','income']).size().unstack().plot(kind='bar',stacked=True)
data_full.groupby(['race','income']).size().unstack().plot(kind='bar',stacked=True)
data_full.groupby(['sex','income']).size().unstack().plot(kind='bar',stacked=True)
data_full.groupby(['native_country','income']).size().unstack().plot(kind='bar',stacked=True)
    
plt.show()

# %%
import math
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15,25))
cols = 3
rows = math.ceil(float(data_full.shape[1])/cols)

for i, column in enumerate(data_full.columns):
    ax = fig.add_subplot(rows, cols, i + 1)
    ax.set_title(column)
    if data_full.dtypes[column] == np.object:
        data_full.groupby([column,'income']).size().unstack().plot(kind='bar',stacked=True)
        #data_full[column].groupby([column, 'income']).value_counts().plot(kind="bar", axes=ax, stacked=True)
    else:
        data_full[column].hist(axes=ax)
        plt.xticks(rotation="vertical")
        
plt.subplots_adjust(hspace=1.0, wspace=0.2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-85-02fc3534b605> in <module>()
#      13         #data_full[column].groupby([column, 'income']).value_counts().plot(kind="bar", axes=ax, stacked=True)
#      14     else:
# ---> 15         data_full[column].hist(axes=ax)
#      16         plt.xticks(rotation="vertical")
#      17
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/plotting/_core.py in hist_series(self, by, ax, grid, xlabelsize, xrot, ylabelsize, yrot, figsize, bins, **kwds)
#    2479         values = self.dropna().values
#    2480
# -> 2481         ax.hist(values, bins=bins, **kwds)
#    2482         ax.grid(grid)
#    2483         axes = np.array([ax])
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.models import ColumnDataSource, HBar

# %%
#BOKEH

output_notebook()

less_50k = df_encoded[df_encoded['income'] == 0]  # <=50K ==0
more_50k = df_encoded[df_encoded['income'] == 1]  # >50K ==1

less50k_cds = ColumnDataSource(less_50k)
more50k_cds = ColumnDataSource(more_50k)

fig = figure()

fig.line()

show(fig)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6417">Loading BokehJS ...</span>
#     </div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-ba7dfb5d6fd2> in <module>()
#      11 fig = figure()
#      12
# ---> 13 fig.hbar_stack(data_full)
#      14
#      15 show(fig)
#
# ~/anaconda3/envs/learn-env/lib/python3.6/site-packages/bokeh/plotting/figure.py in hbar_stack(self, stackers, **kw)
#     914         result = []
#     915         for kw in _stack(stackers, "left", "right", **kw):
# --> 916             result.append(self.hbar(**kw))
#     917         return result
#     918
#
# TypeError: hbar() missing 2 required positional arguments: 'y' and 'height'

# %%
output_notebook()

table = pd.pivot_table(data=df_encoded, index='workclass', 
                        columns='income', aggfunc='count')
                        
#chart_values = list(table.ix['female'].values)
for item in (list(table.ix['income'].values)):
    chart_values.append(item)

#output_file("bokeh_barchart_example.html", title="Bokeh Bar Chart Example")

chart_data = {
    'survival': ['Not Survived', 'Survived', 'Not Survived', 'Survived'],
    #'gender': ['female', 'female', 'male', 'male'],
    'quantity': chart_values
}

bar = Bar(chart_data, values='quantity', label='gender', stack='survival', 
          title="Titanic Survival by Gender - Stacked", legend='top_left')

show(hplot(bar))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="6484">Loading BokehJS ...</span>
#     </div>
# /Users/natalia/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:7: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   import sys
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
from bokeh.core.properties import value
from bokeh.io import show, output_notebook
from bokeh.plotting import figure

output_notebook()

fruits = ['Apples', 'Pears', 'Nectarines', 'Plums', 'Grapes', 'Strawberries']
years = ["2015", "2016", "2017"]
colors = ["#c9d9d3", "#718dbf", "#e84d60"]

data = {'fruits' : fruits,
        '2015'   : [2, 1, 4, 3, 2, 4],
        '2016'   : [5, 3, 4, 2, 4, 6],
        '2017'   : [3, 2, 4, 4, 5, 3]}

p = figure(x_range=fruits, plot_height=250, title="Fruit Counts by Year",
           toolbar_location=None, tools="")

p.vbar_stack(years, x='fruits', width=0.9, color=colors, source=data,
             legend=[value(x) for x in years])



show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5751">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="41874719-3894-412f-b558-1af79e629c83" data-root-id="5753"></div>

# %%
data_full.groupby(['age','income']).size().unstack().plot(kind='line',stacked=True)

# %% [markdown]
# http://bokeh.pydata.org/en/latest/docs/user_guide/categorical.html
# https://realpython.com/python-data-visualization-bokeh/
# https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Bokeh_Cheat_Sheet.pdf
